# %%
# 문제 02) 배열 제어하기
def solution(lst):
    lst = list(set(lst))
    lst.sort(reverse = True)

    return lst

print(solution([4, 2, 2, 1, 3, 4])) # 반환값 : [4, 3, 2, 1]
print(solution([2, 1, 1, 3, 2, 5, 4])) # 반환값 : [5, 4, 3, 2, 1]
# Out:
# [4, 3, 2, 1]
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## **합격자가 되는 모의 테스트**

# %% [markdown]
# #### **문제 03 두 개 뽑아서 더하기**

# %%
def solution(numbers):
    answer = []

    for i in range(len(numbers)):
        for j in range(i+1, len(numbers)):
            answer.append(numbers[i] + numbers[j])
            answer = list(set(answer))
    return answer

print(solution([2, 1, 3, 4, 1]))  # 반환 값: [2, 3, 4, 5, 6, 7]
print(solution([5, 0, 2, 7])) # 반환 값: [2, 5, 7, 9, 12]
# Out:
# [2, 3, 4, 5, 6, 7]
# [2, 5, 7, 9, 12]

# %% [markdown]
# #### **문제 04 모의고사**

# %%
def solution(answers):
    answer = []
    sheet = { 1 : [1, 2, 3, 4, 5], 2: [2, 1, 2, 3, 2, 4, 2, 5], 3: [3, 3, 1, 1, 2, 2, 4, 4, 5, 5]}
    cnt1, cnt2, cnt3 = 0, 0, 0

    for i in range(len(answers)):
        ans = answers[i]
        if sheet[1][i] == ans:cnt1 += 1
        if sheet[2][i] == ans:cnt2 += 1
        if sheet[3][i] == ans:cnt3 += 1

    if cnt1 > cnt2 and cnt1 > cnt3:
        answer.append(1)
    elif cnt2 > cnt1 and cnt2 > cnt3:
        answer.append(2)
    elif cnt3 > cnt1 and cnt3 > cnt2:
        answer.append(3)
    elif cnt1 == cnt2 and cnt1 > cnt3:
        answer.append(1)
        answer.append(2)
    elif cnt1 == cnt3 and cnt1 > cnt2:
        answer.append(1)
        answer.append(3)
    elif cnt2 == cnt3 and cnt2 > cnt1:
        answer.append(2)
        answer.append(3)
    elif cnt1 == cnt2 and cnt2 == cnt3:
        answer.append(1)
        answer.append(2)
        answer.append(3)

    return answer
print(solution([1, 2, 3, 4, 5]))  # 반환 값: [1]
print(solution([1, 3, 2, 4, 2])) # 반환 값: [1, 2, 3]

## 가장 높은 점수를 받은 사람이 여럿이라면 반환하는 값을 오름차순으로 정렬
# Out:
# [1]
# [1, 2, 3]

# %% [markdown]
# ## **문제 05 행렬의 곱셈**
#
# https://school.programmers.co.kr/learn/courses/30/lessons/12949

# %%
def solution(arr1, arr2):
    answer = [[]*len(arr1)]
    for row in range(len(arr1)):
        txt = 1
        for i in (arr1[row]):
            for col in range(len(arr2)):
                for j in arr2[col]:
                    pass

    #     for col in arr2:


    return answer


print(solution([[1, 4], [3, 2], [4, 1]], [[3, 3], [3, 3]]))
print(solution([[2, 3, 2], [4, 2, 4], [3, 1, 4]], [[5, 4, 3], [2, 4, 1], [3, 1, 1]]))
# Out:
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [3, 3]
# [[]]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [5, 4, 3]
# [2, 4, 1]
# [3, 1, 1]
# [[]]
